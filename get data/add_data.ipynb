# %% [markdown]
# # Imports

# %%
import pandas as pd
import os

# %%
df_miss=pd.read_csv('../data/data_miss_2011_2024.csv')

# %%
df_miss
# Out:
#                Région                 Nom  Âge  Taille  \
# 0         Miss Alsace    Mathilde Buecher   19    1.78
# 1      Miss Aquitaine      Clémence Thill   20    1.75
# 2       Miss Auvergne     Clémence Oleksy   19    1.76
# 3      Miss Bourgogne  Alice Detollenaere   23    1.74
# 4       Miss Bretagne     Laury Thilleman   19    1.78
# ..                ...                 ...  ...     ...
# 429     Miss Provence       Adélina Blanc   25    1.73
# 430      Miss Réunion      Mélanie Odules   20    1.78
# 431  Miss Rhône-Alpes       Alizée Bidaut   22    1.74
# 432   Miss Roussillon      Élise Aquilina   21    1.71
# 433       Miss Tahiti    Ravahere Silloux   25    1.72
#
#                    Résidence                  Date élection  \
# 0                Heimersdorf  2010-10-10 00:00:00.000000000
# 1                       Agen  2010-10-16 00:00:00.000000000
# 2                      Vichy  2010-10-17 00:00:00.000000000
# 3           Chitry-les-Mines  2017-09-29 00:00:00.000000000
# 4                      Brest  2010-10-26 00:00:00.000000000
# ..                       ...                            ...
# 429                 Eyragues  2023-07-27 00:00:00.000000000
# 430               Saint-Paul  2023-08-26 00:00:00.000000000
# 431  Saint-Genis-sur-Menthon  2023-09-23 00:00:00.000000000
# 432                Cabestany  2023-08-05 00:00:00.000000000
# 433                  Papeete  2023-06-23 00:00:00.000000000
#
#                                   Classement Final  année  Top 15/12  \
# 0                                              NaN   2011      False
# 1                                              NaN   2011      False
# 2                                      2e dauphine   2011       True
# 3                              Prix du Mannequinat   2011      False
# 4    Miss France 2011\nPrix de la Culture générale   2011       True
# ..                                             ...    ...        ...
# 429                                    2e dauphine   2024       True
# 430                                            NaN   2024      False
# 431                                            NaN   2024      False
# 432  Top 15 (11e)\nPrix de l’académie des Miss[25]   2024       True
# 433                           Top 15 (6e dauphine)   2024       True
#
#      Points_du_public  Points_du_jury  Points_totaux  top_5  Classement  \
# 0                   0               0              0  False         NaN
# 1                   0               0              0  False         NaN
# 2                  10              12             22   True         3.0
# 3                   0               0              0  False         NaN
# 4                  12              11             23   True         1.0
# ..                ...             ...            ...    ...         ...
# 429                12              11             23   True         3.0
# 430                 0               0              0  False         NaN
# 431                 0               0              0  False         NaN
# 432                 6               6             12  False         NaN
# 433                 8               8             16  False         NaN
#
#      ID_REGION
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 429         28
# 430         29
# 431         30
# 432         31
# 433         33
#
# [434 rows x 15 columns]

# %% [markdown]
# # Couverture magasine

# %%
# Ajouter des colonnes pour les nouvelles données
df_miss['Couverture_TeleMagazine'] = False
df_miss['Couverture_TeleLoisirs'] = False

print("Colonnes ajoutées pour les nouvelles informations.")
# Out:
# Colonnes ajoutées pour les nouvelles informations.

# %% [markdown]
# ## Liste des informations sur TéléMagazine

# %%
telemagazine_covers = {
    2024: ['Miss Île-de-France', 'Miss Guadeloupe', 'Miss Normandie', "Miss Côte d'Azur"],
    2023: ['Miss Guadeloupe', "Miss Côte d'Azur", 'Miss Nord-Pas-de-Calais', 'Miss Picardie'],
    2022: ['Miss Île-de-France', "Miss Côte d'Azur", 'Miss Alsace', 'Miss Rhône-Alpes'],
    2021: ['Miss Provence', 'Miss Languedoc-Roussillon', "Miss Côte d'Azur", 'Miss Normandie'],
    2020: ['Miss Provence', 'Miss Bourgogne', 'Miss Martinique'],
    2019: ['Miss Franche-Comté', 'Miss Languedoc-Roussillon', 'Miss Tahiti'],
    2018: ['Miss Nord-Pas-de-Calais', 'Miss Île-de-France', 'Miss Réunion'],
    2017: ['Miss Tahiti', 'Miss Normandie', 'Miss Guyane'],
    2016: ['Miss Réunion', 'Miss Provence', 'Miss Martinique'],
    2015: ["Miss Côte d'Azur", 'Miss Nord-Pas-de-Calais', 'Miss Haute-Savoie'],
    2014: ['Miss Orléanais', 'Miss Tahiti', 'Miss Auvergne'],
    2013: ['Miss Tahiti', 'Miss Bourgogne', 'Miss Languedoc', 'Miss Nouvelle-Calédonie'],
    2012: ['Miss Franche-Comté', 'Miss Tahiti', 'Miss Rhône-Alpes'],
    2011: []
}

# %%
for year, regions in telemagazine_covers.items():
    df_miss.loc[(df_miss['Région'].isin(regions)) & (df_miss['année'] == year), 'Couverture_TeleMagazine'] = True

df_miss['Couverture_TeleMagazine'] = df_miss['Couverture_TeleMagazine'].fillna(False)

print(df_miss[['Région', 'année', 'Couverture_TeleMagazine']].dropna().head(100))
# Out:
#                                    Région  année  Couverture_TeleMagazine
# 0                             Miss Alsace   2011                    False
# 1                          Miss Aquitaine   2011                    False
# 2                           Miss Auvergne   2011                    False
# 3                          Miss Bourgogne   2011                    False
# 4                           Miss Bretagne   2011                    False
# ..                                    ...    ...                      ...
# 95                       Miss Rhône-Alpes   2013                    False
# 96                        Miss Roussillon   2013                    False
# 97  Miss Saint-Martin et Saint-Barthélemy   2013                    False
# 98                            Miss Tahiti   2013                     True
# 99                            Miss Alsace   2014                    False
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Couverture Téléloisir

# %%
df_miss['Couverture_Téléloisir'] = False

teleloisir_2024 = [
    'Miss Nord-Pas-de-Calais', 'Miss Alsace', 'Miss Bourgogne',
    'Miss Pays de la Loire', 'Miss Languedoc-Roussillon', 'Miss Guadeloupe'
]

df_miss.loc[
    (df_miss['Région'].isin(teleloisir_2024)) & (df_miss['année'] == 2024),
    'Couverture_Téléloisir'
] = True

# %%
df_miss_2024 = df_miss[df_miss['année'] == 2024][['Région', 'année', 'Couverture_Téléloisir']]
print(df_miss_2024)
# Out:
#                         Région  année  Couverture_Téléloisir
# 404                Miss Alsace   2024                   True
# 405             Miss Aquitaine   2024                  False
# 406              Miss Auvergne   2024                  False
# 407             Miss Bourgogne   2024                   True
# 408              Miss Bretagne   2024                  False
# 409   Miss Centre-Val-de-Loire   2024                  False
# 410     Miss Champagne-Ardenne   2024                  False
# 411                 Miss Corse   2024                  False
# 412           Miss Côte d'Azur   2024                  False
# 413         Miss Franche-Comté   2024                  False
# 414            Miss Guadeloupe   2024                   True
# 415                Miss Guyane   2024                  False
# 416         Miss Île-de-France   2024                  False
# 417  Miss Languedoc-Roussillon   2024                   True
# 418              Miss Limousin   2024                  False
# 419              Miss Lorraine   2024                  False
# 420            Miss Martinique   2024                  False
# 421               Miss Mayotte   2024                  False
# 422         Miss Midi-Pyrénées   2024                  False
# 423    Miss Nord-Pas-de-Calais   2024                   True
# 424             Miss Normandie   2024                  False
# 425    Miss Nouvelle-Calédonie   2024                  False
# 426      Miss Pays de la Loire   2024                   True
# 427              Miss Picardie   2024                  False
# 428      Miss Poitou-Charentes   2024                  False
# 429              Miss Provence   2024                  False
# 430               Miss Réunion   2024                  False
# 431           Miss Rhône-Alpes   2024                  False
# 432            Miss Roussillon   2024                  False
# 433                Miss Tahiti   2024                  False

# %%
df_miss
# Out:
#                Région                 Nom  Âge  Taille  \
# 0         Miss Alsace    Mathilde Buecher   19    1.78
# 1      Miss Aquitaine      Clémence Thill   20    1.75
# 2       Miss Auvergne     Clémence Oleksy   19    1.76
# 3      Miss Bourgogne  Alice Detollenaere   23    1.74
# 4       Miss Bretagne     Laury Thilleman   19    1.78
# ..                ...                 ...  ...     ...
# 429     Miss Provence       Adélina Blanc   25    1.73
# 430      Miss Réunion      Mélanie Odules   20    1.78
# 431  Miss Rhône-Alpes       Alizée Bidaut   22    1.74
# 432   Miss Roussillon      Élise Aquilina   21    1.71
# 433       Miss Tahiti    Ravahere Silloux   25    1.72
#
#                    Résidence                  Date élection  \
# 0                Heimersdorf  2010-10-10 00:00:00.000000000
# 1                       Agen  2010-10-16 00:00:00.000000000
# 2                      Vichy  2010-10-17 00:00:00.000000000
# 3           Chitry-les-Mines  2017-09-29 00:00:00.000000000
# 4                      Brest  2010-10-26 00:00:00.000000000
# ..                       ...                            ...
# 429                 Eyragues  2023-07-27 00:00:00.000000000
# 430               Saint-Paul  2023-08-26 00:00:00.000000000
# 431  Saint-Genis-sur-Menthon  2023-09-23 00:00:00.000000000
# 432                Cabestany  2023-08-05 00:00:00.000000000
# 433                  Papeete  2023-06-23 00:00:00.000000000
#
#                                   Classement Final  année  Top 15/12  \
# 0                                              NaN   2011      False
# 1                                              NaN   2011      False
# 2                                      2e dauphine   2011       True
# 3                              Prix du Mannequinat   2011      False
# 4    Miss France 2011\nPrix de la Culture générale   2011       True
# ..                                             ...    ...        ...
# 429                                    2e dauphine   2024       True
# 430                                            NaN   2024      False
# 431                                            NaN   2024      False
# 432  Top 15 (11e)\nPrix de l’académie des Miss[25]   2024       True
# 433                           Top 15 (6e dauphine)   2024       True
#
#      Points_du_public  Points_du_jury  Points_totaux  top_5  Classement  \
# 0                   0               0              0  False         NaN
# 1                   0               0              0  False         NaN
# 2                  10              12             22   True         3.0
# 3                   0               0              0  False         NaN
# 4                  12              11             23   True         1.0
# ..                ...             ...            ...    ...         ...
# 429                12              11             23   True         3.0
# 430                 0               0              0  False         NaN
# 431                 0               0              0  False         NaN
# 432                 6               6             12  False         NaN
# 433                 8               8             16  False         NaN
#
#      ID_REGION  Couverture_TeleMagazine  Couverture_TeleLoisirs  \
# 0            1                    False                   False
# 1            2                    False                   False
# 2            3                    False                   False
# 3            4                    False                   False
# 4            5                    False                   False
# ..         ...                      ...                     ...
# 429         28                    False                   False
# 430         29                    False                   False
# 431         30                    False                   False
# 432         31                    False                   False
# 433         33                    False                   False
#
#      Couverture_Téléloisir
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ..                     ...
# 429                  False
# 430                  False
# 431                  False
# 432                  False
# 433                  False
#
# [434 rows x 18 columns]

# %%
dict_cult_g = {
    '2024': {
        '1': {'Candidate': 'Miss Alsace', 'Score': 14.2, 'Rank': 1},
        '2': {'Candidate': 'Miss Limousin', 'Score': 13.3, 'Rank': 2},
        '3': {'Candidate': 'Miss Roussillon', 'Score': 13.3, 'Rank': 2},
        '4': {'Candidate': 'Miss Champagne-Ardenne', 'Score': 12.3, 'Rank': 4}
    },
    '2023': {
        '1': {'Candidate': 'Miss Île-de-France', 'Score': 18.0, 'Rank': 1},
        '2': {'Candidate': 'Miss Nord-Pas-de-Calais', 'Score': 17.0, 'Rank': 2},
        '3': {'Candidate': 'Miss Guadeloupe', 'Score': 16.5, 'Rank': 3}
    },
    '2022': {
        '1': {'Candidate': 'Miss Normandie', 'Score': 17.0, 'Rank': 1},
        '2': {'Candidate': 'Miss Aquitaine', 'Score': 15.5, 'Rank': 2},
        '3': {'Candidate': 'Miss Pays de la Loire', 'Score': 15.0, 'Rank': 3}
    },
    '2021': {
        '1': {'Candidate': 'Miss Bourgogne', 'Score': 17.5, 'Rank': 1}
    },
    '2020': {
        '1': {'Candidate': 'Miss Guadeloupe', 'Score': 17.5, 'Rank': 1}
    },
    '2019': {
        '1': {'Candidate': 'Miss Centre-Val-de-Loire', 'Score': 18.5, 'Rank': 1},
        '2': {'Candidate': 'Miss Limousin', 'Score': 18.3, 'Rank': 2},
        '3': {'Candidate': 'Miss Midi-Pyrénées', 'Score': 18.0, 'Rank': 3}
    },
    '2018': {
        '1': {'Candidate': 'Miss Corse', 'Score': 18.0, 'Rank': 1}
    },
    '2017': {
        '1': {'Candidate': 'Miss Île-de-France', 'Score': 17.0, 'Rank': 1}
    },
    '2016': {
        '1': {'Candidate': 'Miss Nord-Pas-de-Calais', 'Score': 17.5, 'Rank': 1}
    },
    '2015': {
        '1': {'Candidate': 'Miss Île-de-France', 'Score': 19.5, 'Rank': 1}
    },
    '2014': {
        '1': {'Candidate': 'Miss Alsace', 'Score': 18.0, 'Rank': 1}
    },
    '2013': {
        '1': {'Candidate': 'Miss Bourgogne', 'Score': 17.0, 'Rank': 1}
    },
    '2013': {
        '1': {'Candidate': 'Miss Côte d\'Azur', 'Score': 0.0, 'Rank': 1}
    }
}

# %%
df_miss['Score_Culture_G'] = 0.0
df_miss['Rank_Culture_G'] = 30
df_miss['Top_Culture_G'] = False

for year, candidates in dict_cult_g.items():
    for _, data in candidates.items():
        candidate_name = data['Candidate']
        score = data['Score']
        rank = data['Rank']
        
        condition = (df_miss['Région'] == candidate_name) & (df_miss['année'] == int(year))
        
        if condition.any():
            df_miss.loc[condition, 'Score_Culture_G'] = score
            df_miss.loc[condition, 'Rank_Culture_G'] = rank
            df_miss.loc[condition, 'Top_Culture_G'] = True

print(df_miss[['Région', 'année', 'Score_Culture_G', 'Rank_Culture_G', 'Top_Culture_G']].dropna())
# Out:
#                Région  année  Score_Culture_G  Rank_Culture_G  Top_Culture_G
# 0         Miss Alsace   2011              0.0              30          False
# 1      Miss Aquitaine   2011              0.0              30          False
# 2       Miss Auvergne   2011              0.0              30          False
# 3      Miss Bourgogne   2011              0.0              30          False
# 4       Miss Bretagne   2011              0.0              30          False
# ..                ...    ...              ...             ...            ...
# 429     Miss Provence   2024              0.0              30          False
# 430      Miss Réunion   2024              0.0              30          False
# 431  Miss Rhône-Alpes   2024              0.0              30          False
# 432   Miss Roussillon   2024             13.3               2           True
# 433       Miss Tahiti   2024              0.0              30          False
#
# [434 rows x 5 columns]
